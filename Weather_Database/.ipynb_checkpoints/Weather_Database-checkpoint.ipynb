# %%
import pandas as pd
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime
import requests
import sys, traceback
from config import g_key
from config import weather_api_key
import time
from scipy.stats import linregress

# %%
lats = np.random.uniform(low = -90.000,high=90.000,size=2000)
lngs = np.random.uniform(low= -90.000,high=90.000,size=2000)
lats_lngs = zip(lats,lngs)
lats_lngs

# %%
coordinates = list(lats_lngs)

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []
print("Begining Data Retrieval")
print("-----------------------")
record_count = 1
set_count = 1
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
for i,city in enumerate(cities):
    if(i%50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    city_url = url + "&q=" + city.replace(" " ,"+")
    print(city_url)
    print(f"processing Record {record_count} of set {set_count} | {city}")
    record_count +=1
    try:
        city_weather = requests.get(city_url).json()
        print(city_weather)
        city_lat =  city_weather["coord"]["lat"]
        city_lng =  city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds =  city_weather["clouds"]["all"]
        city_wind =  city_weather["wind"]["speed"]
        city_country =  city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_data.append({"City" : city.title(),
                           "Lat" : city_lat,
                           "Lng" : city_lng,
                          "Max Temp" : city_max_temp,
                          "Humidity" : city_humidity,
                          "Cloudiness" : city_clouds,
                          "Wind Speed" : city_wind,
                          "Country"   : city_country,
                          "Date"    : city_date,
                          "Current Description" : city_weather_description})
        
    except:
        print("City not Found Skipping.....")
        pass
print("---------------------------------")
print("Data Retrieval Complete")
print("----------------------------------")
# Out:
# Begining Data Retrieval
# -----------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=turbat
# processing Record 1 of set 1 | turbat
# {'coord': {'lon': 63.044, 'lat': 26.0023}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 93.33, 'feels_like': 103.3, 'temp_min': 93.33, 'temp_max': 93.33, 'pressure': 995, 'humidity': 53, 'sea_level': 995, 'grnd_level': 980}, 'visibility': 10000, 'wind': {'speed': 14.12, 'deg': 168, 'gust': 12.95}, 'clouds': {'all': 100}, 'dt': 1627568756, 'sys': {'country': 'PK', 'sunrise': 1627521127, 'sunset': 1627569375}, 'timezone': 18000, 'id': 1163054, 'name': 'Turbat', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=tazovskiy
# processing Record 2 of set 1 | tazovskiy
# {'coord': {'lon': 78.7, 'lat': 67.4667}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 59.22, 'feels_like': 58.64, 'temp_min': 59.22, 'temp_max': 59.22, 'pressure': 1003, 'humidity': 81, 'sea_level': 1003, 'grnd_level': 1000}, 'visibility': 10000, 'wind': {'speed': 15.48, 'deg': 114, 'gust': 26.69}, 'rain': {'1h': 0.22}, 'clouds': {'all': 43}, 'dt': 1627568756, 'sys': {'country': 'RU', 'sunrise': 1627505706, 'sunset': 1627577282}, 'timezone': 18000, 'id': 1489853, 'name': 'Tazovsky', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=snizhne
# processing Record 3 of set 1 | snizhne
# {'coord': {'lon': 38.7723, 'lat': 48.0261}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 86.2, 'feels_like': 85.06, 'temp_min': 86.2, 'temp_max': 86.2, 'pressure': 1011, 'humidity': 37, 'sea_level': 1011, 'grnd_level': 979}, 'visibility': 10000, 'wind': {'speed': 11.18, 'deg': 232, 'gust': 12.28}, 'clouds': {'all': 12}, 'dt': 1627568756, 'sys': {'country': 'UA', 'sunrise': 1627523822, 'sunset': 1627578331}, 'timezone': 10800, 'id': 693381, 'name': 'Snizhne', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=tsihombe
# processing Record 4 of set 1 | tsihombe
# {'cod': '404', 'message': 'city not found'}
# City not Found Skipping.....
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=tasiilaq
# processing Record 5 of set 1 | tasiilaq
# {'coord': {'lon': -37.6368, 'lat': 65.6145}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 57.36, 'feels_like': 55.85, 'temp_min': 57.36, 'temp_max': 57.36, 'pressure': 1020, 'humidity': 65, 'sea_level': 1020, 'grnd_level': 1016}, 'visibility': 10000, 'wind': {'speed': 2.39, 'deg': 299, 'gust': 3.24}, 'clouds': {'all': 60}, 'dt': 1627568757, 'sys': {'type': 1, 'id': 81, 'country': 'GL', 'sunrise': 1627535453, 'sunset': 1627603376}, 'timezone': -7200, 'id': 3424607, 'name': 'Tasiilaq', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=oriximina
# processing Record 6 of set 1 | oriximina
# {'coord': {'lon': -55.8661, 'lat': -1.7656}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 87.31, 'feels_like': 89.26, 'temp_min': 87.31, 'temp_max': 87.31, 'pressure': 1015, 'humidity': 48, 'sea_level': 1015, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 2.66, 'deg': 111, 'gust': 6.26}, 'clouds': {'all': 91}, 'dt': 1627568757, 'sys': {'country': 'BR', 'sunrise': 1627552122, 'sunset': 1627595457}, 'timezone': -10800, 'id': 3393471, 'name': 'Oriximiná', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=lethem
# processing Record 7 of set 1 | lethem
# {'coord': {'lon': -59.7968, 'lat': 3.3803}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 78.84, 'feels_like': 78.84, 'temp_min': 78.84, 'temp_max': 78.84, 'pressure': 1016, 'humidity': 78, 'sea_level': 1016, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 4.59, 'deg': 48, 'gust': 6.08}, 'clouds': {'all': 96}, 'dt': 1627568758, 'sys': {'country': 'GY', 'sunrise': 1627552648, 'sunset': 1627596818}, 'timezone': -14400, 'id': 3379316, 'name': 'Lethem', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=vilcun
# processing Record 8 of set 1 | vilcun
# {'coord': {'lon': -72.2333, 'lat': -38.65}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 38.14, 'feels_like': 38.14, 'temp_min': 38.14, 'temp_max': 38.14, 'pressure': 1018, 'humidity': 69, 'sea_level': 1018, 'grnd_level': 977}, 'visibility': 10000, 'wind': {'speed': 0.96, 'deg': 46, 'gust': 2.17}, 'clouds': {'all': 0}, 'dt': 1627568758, 'sys': {'type': 1, 'id': 8527, 'country': 'CL', 'sunrise': 1627559597, 'sunset': 1627595837}, 'timezone': -14400, 'id': 3868210, 'name': 'Vilcún', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=ushuaia
# processing Record 9 of set 1 | ushuaia
# {'coord': {'lon': -68.3, 'lat': -54.8}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 46.06, 'feels_like': 38.28, 'temp_min': 46.06, 'temp_max': 47.82, 'pressure': 989, 'humidity': 42}, 'visibility': 10000, 'wind': {'speed': 20.71, 'deg': 290}, 'clouds': {'all': 40}, 'dt': 1627568701, 'sys': {'type': 1, 'id': 8303, 'country': 'AR', 'sunrise': 1627561624, 'sunset': 1627591923}, 'timezone': -10800, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=maniitsoq
# processing Record 10 of set 1 | maniitsoq
# {'coord': {'lon': -52.9, 'lat': 65.4167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 45.91, 'feels_like': 45.91, 'temp_min': 45.91, 'temp_max': 45.91, 'pressure': 1022, 'humidity': 78, 'sea_level': 1022, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 1.61, 'deg': 355, 'gust': 3.29}, 'clouds': {'all': 99}, 'dt': 1627568759, 'sys': {'country': 'GL', 'sunrise': 1627539280, 'sunset': 1627606875}, 'timezone': -7200, 'id': 3421982, 'name': 'Maniitsoq', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=chuy
# processing Record 11 of set 1 | chuy
# {'coord': {'lon': -53.4616, 'lat': -33.6971}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 46.65, 'feels_like': 41.04, 'temp_min': 46.65, 'temp_max': 46.65, 'pressure': 1026, 'humidity': 66, 'sea_level': 1026, 'grnd_level': 1024}, 'visibility': 10000, 'wind': {'speed': 12.57, 'deg': 250, 'gust': 17.65}, 'clouds': {'all': 14}, 'dt': 1627568759, 'sys': {'country': 'UY', 'sunrise': 1627554478, 'sunset': 1627591947}, 'timezone': -10800, 'id': 3443061, 'name': 'Chui', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=hermanus
# processing Record 12 of set 1 | hermanus
# {'coord': {'lon': 19.2345, 'lat': -34.4187}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 59.81, 'feels_like': 59.16, 'temp_min': 55.9, 'temp_max': 59.81, 'pressure': 1027, 'humidity': 78, 'sea_level': 1027, 'grnd_level': 1023}, 'visibility': 10000, 'wind': {'speed': 8.43, 'deg': 328, 'gust': 12.21}, 'clouds': {'all': 83}, 'dt': 1627568759, 'sys': {'type': 2, 'id': 2006131, 'country': 'ZA', 'sunrise': 1627537125, 'sunset': 1627574406}, 'timezone': 7200, 'id': 3366880, 'name': 'Hermanus', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=klaksvik
# processing Record 13 of set 1 | klaksvik
# {'coord': {'lon': -6.589, 'lat': 62.2266}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 58.12, 'feels_like': 58.1, 'temp_min': 58.12, 'temp_max': 58.12, 'pressure': 1004, 'humidity': 95, 'sea_level': 1004, 'grnd_level': 1001}, 'visibility': 10000, 'wind': {'speed': 7.9, 'deg': 51, 'gust': 9.15}, 'clouds': {'all': 100}, 'dt': 1627568760, 'sys': {'type': 1, 'id': 1596, 'country': 'FO', 'sunrise': 1627530167, 'sunset': 1627593759}, 'timezone': 3600, 'id': 2618795, 'name': 'Klaksvík', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=bulawayo
# processing Record 14 of set 1 | bulawayo
# {'coord': {'lon': 28.5833, 'lat': -20.15}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 70.63, 'feels_like': 68.52, 'temp_min': 70.63, 'temp_max': 70.63, 'pressure': 1020, 'humidity': 24, 'sea_level': 1020, 'grnd_level': 874}, 'visibility': 10000, 'wind': {'speed': 9.62, 'deg': 136, 'gust': 8.25}, 'clouds': {'all': 9}, 'dt': 1627568760, 'sys': {'country': 'ZW', 'sunrise': 1627533410, 'sunset': 1627573633}, 'timezone': 7200, 'id': 894701, 'name': 'Bulawayo', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=maceio
# processing Record 15 of set 1 | maceio
# {'coord': {'lon': -35.7353, 'lat': -9.6658}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 83.64, 'feels_like': 87.19, 'temp_min': 83.64, 'temp_max': 83.64, 'pressure': 1017, 'humidity': 61}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 100}, 'clouds': {'all': 40}, 'dt': 1627568761, 'sys': {'type': 1, 'id': 8413, 'country': 'BR', 'sunrise': 1627547936, 'sunset': 1627589979}, 'timezone': -10800, 'id': 3395981, 'name': 'Maceió', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=velasco+ibarra
# processing Record 16 of set 1 | velasco ibarra
# {'coord': {'lon': -79.6167, 'lat': -1.05}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 71.69, 'feels_like': 72.79, 'temp_min': 71.69, 'temp_max': 71.69, 'pressure': 1013, 'humidity': 90, 'sea_level': 1013, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 4.23, 'deg': 191, 'gust': 6.04}, 'clouds': {'all': 100}, 'dt': 1627568761, 'sys': {'country': 'EC', 'sunrise': 1627557764, 'sunset': 1627601215}, 'timezone': -18000, 'id': 3650273, 'name': 'Velasco Ibarra', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=severodvinsk
# processing Record 17 of set 1 | severodvinsk
# {'coord': {'lon': 39.8302, 'lat': 64.5635}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 64.51, 'feels_like': 64.04, 'temp_min': 64.51, 'temp_max': 64.51, 'pressure': 1001, 'humidity': 72, 'sea_level': 1001, 'grnd_level': 1001}, 'visibility': 10000, 'wind': {'speed': 10.07, 'deg': 4, 'gust': 12.08}, 'rain': {'1h': 0.12}, 'clouds': {'all': 100}, 'dt': 1627568762, 'sys': {'type': 1, 'id': 8922, 'country': 'RU', 'sunrise': 1627517594, 'sunset': 1627584051}, 'timezone': 10800, 'id': 496285, 'name': 'Severodvinsk', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=busselton
# processing Record 18 of set 1 | busselton
# {'coord': {'lon': 115.3333, 'lat': -33.65}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 51.04, 'feels_like': 48.99, 'temp_min': 51.04, 'temp_max': 52.09, 'pressure': 1000, 'humidity': 67, 'sea_level': 1000, 'grnd_level': 999}, 'visibility': 10000, 'wind': {'speed': 29.26, 'deg': 271, 'gust': 44.27}, 'clouds': {'all': 100}, 'dt': 1627568762, 'sys': {'type': 2, 'id': 2020551, 'country': 'AU', 'sunrise': 1627513982, 'sunset': 1627551422}, 'timezone': 28800, 'id': 2075265, 'name': 'Busselton', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=ribeira+grande
# processing Record 19 of set 1 | ribeira grande
# {'coord': {'lon': -28.7, 'lat': 38.5167}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 75.6, 'feels_like': 76.28, 'temp_min': 75.6, 'temp_max': 75.6, 'pressure': 1027, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 50}, 'clouds': {'all': 75}, 'dt': 1627568762, 'sys': {'type': 1, 'id': 6883, 'country': 'PT', 'sunrise': 1627541643, 'sunset': 1627592896}, 'timezone': 0, 'id': 3372707, 'name': 'Ribeira Grande', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=longyearbyen
# processing Record 20 of set 1 | longyearbyen
# {'coord': {'lon': 15.6401, 'lat': 78.2186}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 46.24, 'feels_like': 41.67, 'temp_min': 46.24, 'temp_max': 46.24, 'pressure': 1010, 'humidity': 71}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 360}, 'clouds': {'all': 75}, 'dt': 1627568763, 'sys': {'type': 1, 'id': 1663, 'country': 'SJ', 'sunrise': 0, 'sunset': 0}, 'timezone': 7200, 'id': 2729907, 'name': 'Longyearbyen', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=viedma
# processing Record 21 of set 1 | viedma
# {'coord': {'lon': -62.9967, 'lat': -40.8135}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 52.5, 'feels_like': 49.14, 'temp_min': 52.5, 'temp_max': 52.5, 'pressure': 1019, 'humidity': 36, 'sea_level': 1019, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 6.06, 'deg': 327, 'gust': 7.38}, 'clouds': {'all': 0}, 'dt': 1627568763, 'sys': {'country': 'AR', 'sunrise': 1627557680, 'sunset': 1627593321}, 'timezone': -10800, 'id': 3832899, 'name': 'Viedma', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=castro
# processing Record 22 of set 1 | castro
# {'coord': {'lon': -50.0119, 'lat': -24.7911}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 40.78, 'feels_like': 35.19, 'temp_min': 40.78, 'temp_max': 40.78, 'pressure': 1027, 'humidity': 43, 'sea_level': 1027, 'grnd_level': 910}, 'visibility': 10000, 'wind': {'speed': 8.72, 'deg': 203, 'gust': 13.09}, 'clouds': {'all': 3}, 'dt': 1627568763, 'sys': {'country': 'BR', 'sunrise': 1627552705, 'sunset': 1627592064}, 'timezone': -10800, 'id': 3466704, 'name': 'Castro', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=boda
# processing Record 23 of set 1 | boda
# {'coord': {'lon': 17.4695, 'lat': 4.3189}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 84.36, 'feels_like': 87.58, 'temp_min': 84.36, 'temp_max': 84.36, 'pressure': 1009, 'humidity': 58, 'sea_level': 1009, 'grnd_level': 953}, 'visibility': 10000, 'wind': {'speed': 4.36, 'deg': 281, 'gust': 5.75}, 'rain': {'1h': 0.26}, 'clouds': {'all': 61}, 'dt': 1627568764, 'sys': {'country': 'CF', 'sunrise': 1627534026, 'sunset': 1627578352}, 'timezone': 3600, 'id': 2388614, 'name': 'Boda', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=dingle
# processing Record 24 of set 1 | dingle
# {'coord': {'lon': 122.6711, 'lat': 10.9995}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 78.37, 'feels_like': 80.04, 'temp_min': 78.37, 'temp_max': 78.37, 'pressure': 1011, 'humidity': 88, 'sea_level': 1011, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 6.76, 'deg': 211, 'gust': 13.31}, 'clouds': {'all': 100}, 'dt': 1627568764, 'sys': {'country': 'PH', 'sunrise': 1627508216, 'sunset': 1627553666}, 'timezone': 28800, 'id': 1714733, 'name': 'Dingle', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=bredasdorp
# processing Record 25 of set 1 | bredasdorp
# {'coord': {'lon': 20.0403, 'lat': -34.5322}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 59.29, 'feels_like': 58.62, 'temp_min': 59.29, 'temp_max': 59.29, 'pressure': 1027, 'humidity': 79, 'sea_level': 1027, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 5.95, 'deg': 290, 'gust': 11.54}, 'clouds': {'all': 100}, 'dt': 1627568765, 'sys': {'type': 2, 'id': 2006131, 'country': 'ZA', 'sunrise': 1627536945, 'sunset': 1627574199}, 'timezone': 7200, 'id': 1015776, 'name': 'Bredasdorp', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=illoqqortoormiut
# processing Record 26 of set 1 | illoqqortoormiut
# {'cod': '404', 'message': 'city not found'}
# City not Found Skipping.....
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=dikson
# processing Record 27 of set 1 | dikson
# {'coord': {'lon': 80.5464, 'lat': 73.5069}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 42.04, 'feels_like': 34.18, 'temp_min': 42.04, 'temp_max': 42.04, 'pressure': 1013, 'humidity': 85, 'sea_level': 1013, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 15.95, 'deg': 62, 'gust': 19.35}, 'clouds': {'all': 100}, 'dt': 1627568766, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 25200, 'id': 1507390, 'name': 'Dikson', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=hof
# processing Record 28 of set 1 | hof
# {'coord': {'lon': 11.9167, 'lat': 50.3167}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 71.64, 'feels_like': 70.75, 'temp_min': 67.1, 'temp_max': 76.44, 'pressure': 1013, 'humidity': 48}, 'visibility': 10000, 'wind': {'speed': 14.97, 'deg': 230}, 'clouds': {'all': 0}, 'dt': 1627568760, 'sys': {'type': 1, 'id': 1313, 'country': 'DE', 'sunrise': 1627529777, 'sunset': 1627585266}, 'timezone': 7200, 'id': 2902768, 'name': 'Hof', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=olafsvik
# processing Record 29 of set 1 | olafsvik
# {'coord': {'lon': -23.7142, 'lat': 64.8945}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 53.98, 'feels_like': 53.11, 'temp_min': 53.98, 'temp_max': 53.98, 'pressure': 1014, 'humidity': 86, 'sea_level': 1014, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 10.85, 'deg': 55, 'gust': 15.28}, 'clouds': {'all': 87}, 'dt': 1627568766, 'sys': {'country': 'IS', 'sunrise': 1627532647, 'sunset': 1627599498}, 'timezone': 0, 'id': 3414079, 'name': 'Olafsvik', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=jamestown
# processing Record 30 of set 1 | jamestown
# {'coord': {'lon': -79.2353, 'lat': 42.097}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 65.98, 'feels_like': 66.74, 'temp_min': 62.51, 'temp_max': 68.07, 'pressure': 1011, 'humidity': 95}, 'visibility': 10000, 'wind': {'speed': 8.01, 'deg': 183, 'gust': 13}, 'rain': {'1h': 3.76}, 'clouds': {'all': 90}, 'dt': 1627568767, 'sys': {'type': 2, 'id': 2008828, 'country': 'US', 'sunrise': 1627553239, 'sunset': 1627605557}, 'timezone': -14400, 'id': 5122534, 'name': 'Jamestown', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=east+london
# processing Record 31 of set 1 | east london
# {'coord': {'lon': 27.9116, 'lat': -33.0153}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 65.34, 'feels_like': 64.53, 'temp_min': 65.34, 'temp_max': 65.34, 'pressure': 1025, 'humidity': 63}, 'visibility': 10000, 'wind': {'speed': 20.71, 'deg': 220}, 'clouds': {'all': 0}, 'dt': 1627568767, 'sys': {'type': 1, 'id': 1912, 'country': 'ZA', 'sunrise': 1627534879, 'sunset': 1627572487}, 'timezone': 7200, 'id': 1006984, 'name': 'East London', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=puerto+cabezas
# processing Record 32 of set 1 | puerto cabezas
# {'coord': {'lon': -83.3888, 'lat': 14.0351}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 84.16, 'feels_like': 96.04, 'temp_min': 84.16, 'temp_max': 84.16, 'pressure': 1012, 'humidity': 84}, 'visibility': 6000, 'wind': {'speed': 4.61, 'deg': 30}, 'clouds': {'all': 75}, 'dt': 1627568768, 'sys': {'type': 1, 'id': 7181, 'country': 'NI', 'sunrise': 1627557416, 'sunset': 1627603374}, 'timezone': -21600, 'id': 3617154, 'name': 'Puerto Cabezas', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=cape+town
# processing Record 33 of set 1 | cape town
# {'coord': {'lon': 18.4232, 'lat': -33.9258}, 'weather': [{'id': 300, 'main': 'Drizzle', 'description': 'light intensity drizzle', 'icon': '09d'}], 'base': 'stations', 'main': {'temp': 57.67, 'feels_like': 57.36, 'temp_min': 55.27, 'temp_max': 60.12, 'pressure': 1029, 'humidity': 90}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 20}, 'clouds': {'all': 75}, 'dt': 1627568588, 'sys': {'type': 2, 'id': 2033665, 'country': 'ZA', 'sunrise': 1627537261, 'sunset': 1627574659}, 'timezone': 7200, 'id': 3369157, 'name': 'Cape Town', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=markala
# processing Record 34 of set 1 | markala
# {'coord': {'lon': -6.0659, 'lat': 13.7021}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 90.18, 'feels_like': 94.03, 'temp_min': 90.18, 'temp_max': 90.18, 'pressure': 1010, 'humidity': 48, 'sea_level': 1010, 'grnd_level': 978}, 'visibility': 10000, 'wind': {'speed': 1.79, 'deg': 329, 'gust': 2.95}, 'clouds': {'all': 63}, 'dt': 1627568768, 'sys': {'country': 'ML', 'sunrise': 1627538884, 'sunset': 1627584791}, 'timezone': 0, 'id': 2453662, 'name': 'Markala', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=taolanaro
# processing Record 35 of set 1 | taolanaro
# {'cod': '404', 'message': 'city not found'}
# City not Found Skipping.....
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=margate
# processing Record 36 of set 1 | margate
# {'coord': {'lon': 1.3862, 'lat': 51.3813}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 70.07, 'feels_like': 68.9, 'temp_min': 65.88, 'temp_max': 72.7, 'pressure': 1011, 'humidity': 45}, 'visibility': 10000, 'wind': {'speed': 4, 'deg': 200, 'gust': 10}, 'clouds': {'all': 37}, 'dt': 1627568487, 'sys': {'type': 2, 'id': 2020742, 'country': 'GB', 'sunrise': 1627532057, 'sunset': 1627588041}, 'timezone': 3600, 'id': 2643044, 'name': 'Margate', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=nanortalik
# processing Record 37 of set 1 | nanortalik
# {'coord': {'lon': -45.2371, 'lat': 60.1432}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 47.14, 'feels_like': 42.06, 'temp_min': 47.14, 'temp_max': 47.14, 'pressure': 1022, 'humidity': 81, 'sea_level': 1022, 'grnd_level': 1022}, 'visibility': 10000, 'wind': {'speed': 11.25, 'deg': 148, 'gust': 17.05}, 'clouds': {'all': 64}, 'dt': 1627568769, 'sys': {'country': 'GL', 'sunrise': 1627540453, 'sunset': 1627602024}, 'timezone': -7200, 'id': 3421765, 'name': 'Nanortalik', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=jalu
# processing Record 38 of set 1 | jalu
# {'coord': {'lon': 21.5482, 'lat': 29.0331}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 99.88, 'feels_like': 95.99, 'temp_min': 99.88, 'temp_max': 99.88, 'pressure': 1008, 'humidity': 16, 'sea_level': 1008, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 7.16, 'deg': 297, 'gust': 6.2}, 'clouds': {'all': 0}, 'dt': 1627568769, 'sys': {'country': 'LY', 'sunrise': 1627530764, 'sunset': 1627579657}, 'timezone': 7200, 'id': 86049, 'name': 'Jalu', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=shache
# processing Record 39 of set 1 | shache
# {'coord': {'lon': 77.2406, 'lat': 38.4167}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 93.45, 'feels_like': 88.97, 'temp_min': 93.45, 'temp_max': 93.45, 'pressure': 989, 'humidity': 13, 'sea_level': 989, 'grnd_level': 864}, 'visibility': 10000, 'wind': {'speed': 3.49, 'deg': 304, 'gust': 4}, 'clouds': {'all': 0}, 'dt': 1627568770, 'sys': {'country': 'CN', 'sunrise': 1627516216, 'sunset': 1627567472}, 'timezone': 28800, 'id': 1280037, 'name': 'Shache', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=marsa+matruh
# processing Record 40 of set 1 | marsa matruh
# {'coord': {'lon': 27.2453, 'lat': 31.3525}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 86.2, 'feels_like': 90.75, 'temp_min': 86.2, 'temp_max': 86.2, 'pressure': 1008, 'humidity': 58}, 'visibility': 10000, 'wind': {'speed': 14.97, 'deg': 290}, 'clouds': {'all': 0}, 'dt': 1627568770, 'sys': {'type': 1, 'id': 2517, 'country': 'EG', 'sunrise': 1627529131, 'sunset': 1627578555}, 'timezone': 7200, 'id': 352733, 'name': 'Marsá Maţrūḩ', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=gobabis
# processing Record 41 of set 1 | gobabis
# {'coord': {'lon': 18.9667, 'lat': -22.45}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 71.53, 'feels_like': 68.99, 'temp_min': 71.53, 'temp_max': 71.53, 'pressure': 1020, 'humidity': 13, 'sea_level': 1020, 'grnd_level': 866}, 'visibility': 10000, 'wind': {'speed': 13.73, 'deg': 97, 'gust': 14.16}, 'clouds': {'all': 0}, 'dt': 1627568771, 'sys': {'country': 'NA', 'sunrise': 1627535931, 'sunset': 1627575728}, 'timezone': 7200, 'id': 3357247, 'name': 'Gobabis', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=boa+vista
# processing Record 42 of set 1 | boa vista
# {'coord': {'lon': -60.6733, 'lat': 2.8197}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 76.98, 'feels_like': 78.04, 'temp_min': 76.98, 'temp_max': 76.98, 'pressure': 1017, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 40}, 'clouds': {'all': 90}, 'dt': 1627568722, 'sys': {'type': 1, 'id': 8340, 'country': 'BR', 'sunrise': 1627552904, 'sunset': 1627596982}, 'timezone': -14400, 'id': 3664980, 'name': 'Boa Vista', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=wa
# processing Record 43 of set 1 | wa
# {'cod': '404', 'message': 'city not found'}
# City not Found Skipping.....
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=sept-iles
# processing Record 44 of set 1 | sept-iles
# {'coord': {'lon': -66.3821, 'lat': 50.2001}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 64.38, 'feels_like': 63.66, 'temp_min': 59.43, 'temp_max': 65.05, 'pressure': 1008, 'humidity': 67}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 240, 'gust': 8.01}, 'clouds': {'all': 75}, 'dt': 1627568771, 'sys': {'type': 2, 'id': 2006302, 'country': 'CA', 'sunrise': 1627548614, 'sunset': 1627604012}, 'timezone': -14400, 'id': 6144312, 'name': 'Sept-Îles', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=richards+bay
# processing Record 45 of set 1 | richards bay
# {'coord': {'lon': 32.0377, 'lat': -28.783}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 71.29, 'feels_like': 69.82, 'temp_min': 71.29, 'temp_max': 71.29, 'pressure': 1022, 'humidity': 36, 'sea_level': 1022, 'grnd_level': 1021}, 'visibility': 10000, 'wind': {'speed': 9.71, 'deg': 186, 'gust': 16.04}, 'clouds': {'all': 0}, 'dt': 1627568772, 'sys': {'country': 'ZA', 'sunrise': 1627533424, 'sunset': 1627571961}, 'timezone': 7200, 'id': 962367, 'name': 'Richards Bay', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=ambilobe
# processing Record 46 of set 1 | ambilobe
# {'coord': {'lon': 49.05, 'lat': -13.2}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 76.35, 'feels_like': 76.69, 'temp_min': 76.35, 'temp_max': 76.35, 'pressure': 1017, 'humidity': 64, 'sea_level': 1017, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 4.45, 'deg': 298, 'gust': 6.87}, 'clouds': {'all': 57}, 'dt': 1627568772, 'sys': {'country': 'MG', 'sunrise': 1627527888, 'sunset': 1627569332}, 'timezone': 10800, 'id': 1082243, 'name': 'Ambilobe', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=cururupu
# processing Record 47 of set 1 | cururupu
# {'coord': {'lon': -44.8683, 'lat': -1.8283}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 88.09, 'feels_like': 93.15, 'temp_min': 88.09, 'temp_max': 88.09, 'pressure': 1014, 'humidity': 55, 'sea_level': 1014, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 5.26, 'deg': 69, 'gust': 7.02}, 'clouds': {'all': 4}, 'dt': 1627568584, 'sys': {'country': 'BR', 'sunrise': 1627549488, 'sunset': 1627592812}, 'timezone': -10800, 'id': 3401148, 'name': 'Cururupu', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=hamilton
# processing Record 48 of set 1 | hamilton
# {'coord': {'lon': -84.5333, 'lat': 39.1834}, 'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}], 'base': 'stations', 'main': {'temp': 77.86, 'feels_like': 79.45, 'temp_min': 74.17, 'temp_max': 80.42, 'pressure': 1015, 'humidity': 87}, 'visibility': 9656, 'wind': {'speed': 1.99, 'deg': 170, 'gust': 3}, 'clouds': {'all': 1}, 'dt': 1627568636, 'sys': {'type': 2, 'id': 2005257, 'country': 'US', 'sunrise': 1627554955, 'sunset': 1627606384}, 'timezone': -14400, 'id': 4513583, 'name': 'Hamilton', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=binika
# processing Record 49 of set 1 | binika
# {'coord': {'lon': 83.8, 'lat': 21.0333}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 76.98, 'feels_like': 78.37, 'temp_min': 76.98, 'temp_max': 76.98, 'pressure': 1001, 'humidity': 85, 'sea_level': 1001, 'grnd_level': 986}, 'visibility': 10000, 'wind': {'speed': 13.4, 'deg': 254, 'gust': 29.17}, 'rain': {'1h': 0.33}, 'clouds': {'all': 100}, 'dt': 1627568773, 'sys': {'country': 'IN', 'sunrise': 1627516642, 'sunset': 1627563898}, 'timezone': 19800, 'id': 1275558, 'name': 'Binka', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=vila+velha
# processing Record 50 of set 1 | vila velha
# {'coord': {'lon': -40.2925, 'lat': -20.3297}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 64.35, 'feels_like': 64.33, 'temp_min': 62.94, 'temp_max': 64.35, 'pressure': 1020, 'humidity': 82}, 'visibility': 10000, 'wind': {'speed': 18.41, 'deg': 200}, 'clouds': {'all': 75}, 'dt': 1627568716, 'sys': {'type': 1, 'id': 8474, 'country': 'BR', 'sunrise': 1627549952, 'sunset': 1627590151}, 'timezone': -10800, 'id': 3445026, 'name': 'Vila Velha', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=barentsburg
# processing Record 1 of set 2 | barentsburg
# {'cod': '404', 'message': 'city not found'}
# City not Found Skipping.....
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=maiduguri
# processing Record 2 of set 2 | maiduguri
# {'coord': {'lon': 13.1603, 'lat': 11.8464}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 79.75, 'feels_like': 79.75, 'temp_min': 79.75, 'temp_max': 79.75, 'pressure': 1010, 'humidity': 71, 'sea_level': 1010, 'grnd_level': 974}, 'visibility': 10000, 'wind': {'speed': 3.83, 'deg': 283, 'gust': 6.89}, 'clouds': {'all': 98}, 'dt': 1627568774, 'sys': {'country': 'NG', 'sunrise': 1627534430, 'sunset': 1627580016}, 'timezone': 3600, 'id': 2331447, 'name': 'Maiduguri', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=port-gentil
# processing Record 3 of set 2 | port-gentil
# {'coord': {'lon': 8.7815, 'lat': -0.7193}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 82.36, 'feels_like': 86.9, 'temp_min': 82.36, 'temp_max': 82.36, 'pressure': 1012, 'humidity': 69}, 'visibility': 10000, 'wind': {'speed': 16.11, 'deg': 200}, 'clouds': {'all': 40}, 'dt': 1627568774, 'sys': {'type': 1, 'id': 2188, 'country': 'GA', 'sunrise': 1627536522, 'sunset': 1627580026}, 'timezone': 3600, 'id': 2396518, 'name': 'Port-Gentil', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=ponnani
# processing Record 4 of set 2 | ponnani
# {'coord': {'lon': 75.9252, 'lat': 10.767}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 79.92, 'feels_like': 79.92, 'temp_min': 79.92, 'temp_max': 79.92, 'pressure': 1011, 'humidity': 84, 'sea_level': 1011, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 8.19, 'deg': 313, 'gust': 15.55}, 'clouds': {'all': 100}, 'dt': 1627568775, 'sys': {'type': 1, 'id': 9209, 'country': 'IN', 'sunrise': 1627519457, 'sunset': 1627564863}, 'timezone': 19800, 'id': 1259411, 'name': 'Ponnāni', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=qaanaaq
# processing Record 5 of set 2 | qaanaaq
# {'coord': {'lon': -69.3632, 'lat': 77.484}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 44.71, 'feels_like': 38.3, 'temp_min': 44.71, 'temp_max': 44.71, 'pressure': 1015, 'humidity': 89, 'sea_level': 1015, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 13.47, 'deg': 84, 'gust': 23.2}, 'rain': {'1h': 0.16}, 'clouds': {'all': 100}, 'dt': 1627568775, 'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0}, 'timezone': -10800, 'id': 3831208, 'name': 'Qaanaaq', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=bengkulu
# processing Record 6 of set 2 | bengkulu
# {'coord': {'lon': 102.2655, 'lat': -3.8004}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 78.39, 'feels_like': 79.97, 'temp_min': 78.39, 'temp_max': 78.39, 'pressure': 1012, 'humidity': 86, 'sea_level': 1012, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 8.61, 'deg': 119, 'gust': 12.48}, 'clouds': {'all': 84}, 'dt': 1627568776, 'sys': {'country': 'ID', 'sunrise': 1627514338, 'sunset': 1627557339}, 'timezone': 25200, 'id': 1649150, 'name': 'Bengkulu', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=alvaraes
# processing Record 7 of set 2 | alvaraes
# {'coord': {'lon': -64.8042, 'lat': -3.2208}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 76.87, 'feels_like': 77.59, 'temp_min': 76.87, 'temp_max': 76.87, 'pressure': 1016, 'humidity': 71, 'sea_level': 1016, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 164, 'gust': 15.39}, 'clouds': {'all': 100}, 'dt': 1627568776, 'sys': {'type': 1, 'id': 8438, 'country': 'BR', 'sunrise': 1627554385, 'sunset': 1627597484}, 'timezone': -14400, 'id': 3665380, 'name': 'Alvarães', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=ndele
# processing Record 8 of set 2 | ndele
# {'coord': {'lon': 20.6473, 'lat': 8.4109}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 83.89, 'feels_like': 87.08, 'temp_min': 83.89, 'temp_max': 83.89, 'pressure': 1009, 'humidity': 59, 'sea_level': 1009, 'grnd_level': 952}, 'visibility': 10000, 'wind': {'speed': 6.31, 'deg': 241, 'gust': 8.28}, 'clouds': {'all': 27}, 'dt': 1627568777, 'sys': {'country': 'CF', 'sunrise': 1627532924, 'sunset': 1627577928}, 'timezone': 3600, 'id': 237379, 'name': 'Ndélé', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=thinadhoo
# processing Record 9 of set 2 | thinadhoo
# {'coord': {'lon': 72.9333, 'lat': 0.5333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 82.31, 'feels_like': 87.26, 'temp_min': 82.31, 'temp_max': 82.31, 'pressure': 1012, 'humidity': 71, 'sea_level': 1012, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 5.82, 'deg': 205, 'gust': 5.95}, 'clouds': {'all': 99}, 'dt': 1627568777, 'sys': {'country': 'MV', 'sunrise': 1627521024, 'sunset': 1627564732}, 'timezone': 18000, 'id': 1337610, 'name': 'Thinadhoo', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=juterbog
# processing Record 10 of set 2 | juterbog
# {'coord': {'lon': 13.0833, 'lat': 51.9833}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 73.51, 'feels_like': 72.86, 'temp_min': 71.71, 'temp_max': 75.85, 'pressure': 1011, 'humidity': 49, 'sea_level': 1011, 'grnd_level': 1002}, 'visibility': 10000, 'wind': {'speed': 13.98, 'deg': 235, 'gust': 24.05}, 'clouds': {'all': 100}, 'dt': 1627568778, 'sys': {'type': 2, 'id': 2038480, 'country': 'DE', 'sunrise': 1627529099, 'sunset': 1627585384}, 'timezone': 7200, 'id': 2894394, 'name': 'Jüterbog', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=swellendam
# processing Record 11 of set 2 | swellendam
# {'coord': {'lon': 20.4417, 'lat': -34.0226}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 55.33, 'feels_like': 53.85, 'temp_min': 55.33, 'temp_max': 55.33, 'pressure': 1027, 'humidity': 70, 'sea_level': 1027, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 5.17, 'deg': 327, 'gust': 7.31}, 'clouds': {'all': 100}, 'dt': 1627568778, 'sys': {'country': 'ZA', 'sunrise': 1627536788, 'sunset': 1627574163}, 'timezone': 7200, 'id': 950709, 'name': 'Swellendam', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=altea
# processing Record 12 of set 2 | altea
# {'coord': {'lon': -0.0514, 'lat': 38.5989}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 83.71, 'feels_like': 89.26, 'temp_min': 80.67, 'temp_max': 87.21, 'pressure': 1014, 'humidity': 68, 'sea_level': 1014, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 7.05, 'deg': 143, 'gust': 6.58}, 'clouds': {'all': 4}, 'dt': 1627568778, 'sys': {'type': 2, 'id': 2006738, 'country': 'ES', 'sunrise': 1627534751, 'sunset': 1627586037}, 'timezone': 7200, 'id': 2521804, 'name': 'Altea', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=la+ligua
# processing Record 13 of set 2 | la ligua
# {'coord': {'lon': -71.2311, 'lat': -32.4524}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 42.58, 'feels_like': 42.58, 'temp_min': 42.58, 'temp_max': 42.58, 'pressure': 1017, 'humidity': 33, 'sea_level': 1017, 'grnd_level': 1000}, 'visibility': 10000, 'wind': {'speed': 1.14, 'deg': 286, 'gust': 0.6}, 'clouds': {'all': 0}, 'dt': 1627568779, 'sys': {'type': 1, 'id': 8520, 'country': 'CL', 'sunrise': 1627558597, 'sunset': 1627596356}, 'timezone': -14400, 'id': 3885456, 'name': 'La Ligua', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=shahkot
# processing Record 14 of set 2 | shahkot
# {'coord': {'lon': 75.3372, 'lat': 31.0775}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 83.14, 'feels_like': 91.99, 'temp_min': 83.14, 'temp_max': 83.14, 'pressure': 995, 'humidity': 81, 'sea_level': 995, 'grnd_level': 970}, 'visibility': 10000, 'wind': {'speed': 3.62, 'deg': 164, 'gust': 3.91}, 'clouds': {'all': 6}, 'dt': 1627568779, 'sys': {'country': 'IN', 'sunrise': 1627517616, 'sunset': 1627566986}, 'timezone': 19800, 'id': 1256725, 'name': 'Shāhkot', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=bubaque
# processing Record 15 of set 2 | bubaque
# {'coord': {'lon': -15.8333, 'lat': 11.2833}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 76.39, 'feels_like': 77.81, 'temp_min': 76.39, 'temp_max': 76.39, 'pressure': 1014, 'humidity': 87, 'sea_level': 1014, 'grnd_level': 1011}, 'visibility': 5752, 'wind': {'speed': 12.41, 'deg': 218, 'gust': 11.83}, 'rain': {'1h': 2.42}, 'clouds': {'all': 100}, 'dt': 1627568780, 'sys': {'country': 'GW', 'sunrise': 1627541438, 'sunset': 1627586926}, 'timezone': 0, 'id': 2374583, 'name': 'Bubaque', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=gambissara
# processing Record 16 of set 2 | gambissara
# {'coord': {'lon': -14.3108, 'lat': 13.2382}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 84.87, 'feels_like': 91.31, 'temp_min': 84.87, 'temp_max': 84.87, 'pressure': 1012, 'humidity': 67, 'sea_level': 1012, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 3.31, 'deg': 207, 'gust': 3.96}, 'clouds': {'all': 93}, 'dt': 1627568780, 'sys': {'country': 'SN', 'sunrise': 1627540904, 'sunset': 1627586729}, 'timezone': 0, 'id': 2413818, 'name': 'Gambissara', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=upernavik
# processing Record 17 of set 2 | upernavik
# {'coord': {'lon': -56.1549, 'lat': 72.7868}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 42.57, 'feels_like': 33.84, 'temp_min': 42.57, 'temp_max': 42.57, 'pressure': 1023, 'humidity': 97, 'sea_level': 1023, 'grnd_level': 1023}, 'visibility': 3208, 'wind': {'speed': 20.07, 'deg': 172, 'gust': 35.19}, 'rain': {'1h': 0.13}, 'clouds': {'all': 100}, 'dt': 1627568780, 'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0}, 'timezone': -7200, 'id': 3418910, 'name': 'Upernavik', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=saint+george
# processing Record 18 of set 2 | saint george
# {'coord': {'lon': -113.5841, 'lat': 37.1041}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 85.08, 'feels_like': 84.79, 'temp_min': 81.07, 'temp_max': 86.63, 'pressure': 1013, 'humidity': 42}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 180, 'gust': 1.99}, 'clouds': {'all': 1}, 'dt': 1627568781, 'sys': {'type': 2, 'id': 2007591, 'country': 'US', 'sunrise': 1627562223, 'sunset': 1627613059}, 'timezone': -21600, 'id': 5546220, 'name': 'Saint George', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=rondonopolis
# processing Record 19 of set 2 | rondonopolis
# {'coord': {'lon': -54.6356, 'lat': -16.4708}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 68.63, 'feels_like': 65.95, 'temp_min': 68.63, 'temp_max': 68.63, 'pressure': 1025, 'humidity': 16, 'sea_level': 1025, 'grnd_level': 998}, 'visibility': 10000, 'wind': {'speed': 8.52, 'deg': 157, 'gust': 11.43}, 'clouds': {'all': 1}, 'dt': 1627568733, 'sys': {'country': 'BR', 'sunrise': 1627553049, 'sunset': 1627593939}, 'timezone': -14400, 'id': 3450909, 'name': 'Rondonópolis', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=qandala
# processing Record 20 of set 2 | qandala
# {'coord': {'lon': 49.8728, 'lat': 11.472}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 90.52, 'feels_like': 98.1, 'temp_min': 90.52, 'temp_max': 90.52, 'pressure': 1004, 'humidity': 55, 'sea_level': 1004, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 7.45, 'deg': 283, 'gust': 15.79}, 'clouds': {'all': 76}, 'dt': 1627568781, 'sys': {'country': 'SO', 'sunrise': 1627525650, 'sunset': 1627571175}, 'timezone': 10800, 'id': 53157, 'name': 'Qandala', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=tingrela
# processing Record 21 of set 2 | tingrela
# {'cod': '404', 'message': 'city not found'}
# City not Found Skipping.....
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=nohar
# processing Record 22 of set 2 | nohar
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=piacabucu
# processing Record 29 of set 15 | piacabucu
# {'coord': {'lon': -36.4344, 'lat': -10.4056}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 81.45, 'feels_like': 84.33, 'temp_min': 81.45, 'temp_max': 81.45, 'pressure': 1016, 'humidity': 64, 'sea_level': 1016, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 6.42, 'deg': 94, 'gust': 4.83}, 'clouds': {'all': 3}, 'dt': 1627569031, 'sys': {'country': 'BR', 'sunrise': 1627548166, 'sunset': 1627590086}, 'timezone': -10800, 'id': 3454005, 'name': 'Piaçabuçu', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=de+aar
# processing Record 30 of set 15 | de aar
# {'coord': {'lon': 24.0123, 'lat': -30.6497}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 61.3, 'feels_like': 58.03, 'temp_min': 61.3, 'temp_max': 61.3, 'pressure': 1024, 'humidity': 19, 'sea_level': 1024, 'grnd_level': 886}, 'visibility': 10000, 'wind': {'speed': 6.11, 'deg': 254, 'gust': 7.78}, 'clouds': {'all': 0}, 'dt': 1627569031, 'sys': {'country': 'ZA', 'sunrise': 1627535549, 'sunset': 1627573688}, 'timezone': 7200, 'id': 1011632, 'name': 'De Aar', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=kusa
# processing Record 31 of set 15 | kusa
# {'coord': {'lon': 59.4406, 'lat': 55.3383}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 62.71, 'feels_like': 61.5, 'temp_min': 62.71, 'temp_max': 62.71, 'pressure': 1010, 'humidity': 60, 'sea_level': 1010, 'grnd_level': 968}, 'visibility': 10000, 'wind': {'speed': 5.14, 'deg': 259, 'gust': 14.9}, 'clouds': {'all': 21}, 'dt': 1627569032, 'sys': {'country': 'RU', 'sunrise': 1627517036, 'sunset': 1627575196}, 'timezone': 18000, 'id': 538442, 'name': 'Kusa', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=sembabule
# processing Record 32 of set 15 | sembabule
# {'coord': {'lon': 31.4567, 'lat': -0.0772}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 79.74, 'feels_like': 79.74, 'temp_min': 79.74, 'temp_max': 79.74, 'pressure': 1011, 'humidity': 39, 'sea_level': 1011, 'grnd_level': 879}, 'visibility': 10000, 'wind': {'speed': 11.52, 'deg': 142, 'gust': 10.13}, 'clouds': {'all': 96}, 'dt': 1627569032, 'sys': {'country': 'UG', 'sunrise': 1627531028, 'sunset': 1627574636}, 'timezone': 10800, 'id': 226361, 'name': 'Sembabule', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=sosua
# processing Record 33 of set 15 | sosua
# {'coord': {'lon': -70.5167, 'lat': 19.7667}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 82.54, 'feels_like': 88.5, 'temp_min': 82.31, 'temp_max': 85.51, 'pressure': 1016, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 120}, 'clouds': {'all': 20}, 'dt': 1627568871, 'sys': {'type': 1, 'id': 7072, 'country': 'DO', 'sunrise': 1627553808, 'sunset': 1627600803}, 'timezone': -14400, 'id': 3492627, 'name': 'El Batey', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=chabahar
# processing Record 34 of set 15 | chabahar
# {'coord': {'lon': 60.643, 'lat': 25.2919}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 86.38, 'feels_like': 98.98, 'temp_min': 86.38, 'temp_max': 86.38, 'pressure': 995, 'humidity': 80, 'sea_level': 995, 'grnd_level': 993}, 'visibility': 10000, 'wind': {'speed': 10.92, 'deg': 151, 'gust': 12.41}, 'clouds': {'all': 92}, 'dt': 1627569033, 'sys': {'country': 'IR', 'sunrise': 1627521777, 'sunset': 1627569878}, 'timezone': 16200, 'id': 1161724, 'name': 'Chabahar', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=linhares
# processing Record 35 of set 15 | linhares
# {'coord': {'lon': -40.0722, 'lat': -19.3911}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 70.84, 'feels_like': 70.74, 'temp_min': 70.84, 'temp_max': 70.84, 'pressure': 1019, 'humidity': 66, 'sea_level': 1019, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 14.05, 'deg': 169, 'gust': 19.35}, 'clouds': {'all': 100}, 'dt': 1627569034, 'sys': {'country': 'BR', 'sunrise': 1627549814, 'sunset': 1627590183}, 'timezone': -10800, 'id': 3458498, 'name': 'Linhares', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=colares
# processing Record 36 of set 15 | colares
# {'coord': {'lon': -9.4469, 'lat': 38.7992}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 75.04, 'feels_like': 74.91, 'temp_min': 69.26, 'temp_max': 82.08, 'pressure': 1015, 'humidity': 57}, 'visibility': 10000, 'wind': {'speed': 14.97, 'deg': 330}, 'clouds': {'all': 20}, 'dt': 1627569034, 'sys': {'type': 2, 'id': 2021330, 'country': 'PT', 'sunrise': 1627536979, 'sunset': 1627588319}, 'timezone': 3600, 'id': 2269142, 'name': 'Colares', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=carnarvon
# processing Record 37 of set 15 | carnarvon
# {'coord': {'lon': 113.6333, 'lat': -24.8667}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 64.47, 'feels_like': 64, 'temp_min': 64.47, 'temp_max': 64.47, 'pressure': 1013, 'humidity': 72}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 300}, 'clouds': {'all': 75}, 'dt': 1627569035, 'sys': {'type': 1, 'id': 9505, 'country': 'AU', 'sunrise': 1627513451, 'sunset': 1627552769}, 'timezone': 28800, 'id': 2074865, 'name': 'Carnarvon', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=sao+gabriel
# processing Record 38 of set 15 | sao gabriel
# {'coord': {'lon': -54.32, 'lat': -30.3364}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 46.71, 'feels_like': 42.57, 'temp_min': 46.71, 'temp_max': 46.71, 'pressure': 1030, 'humidity': 59, 'sea_level': 1030, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 8.46, 'deg': 242, 'gust': 10.65}, 'clouds': {'all': 2}, 'dt': 1627569028, 'sys': {'country': 'BR', 'sunrise': 1627554306, 'sunset': 1627592530}, 'timezone': -10800, 'id': 3449099, 'name': 'São Gabriel', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=nueva+gorgona
# processing Record 39 of set 15 | nueva gorgona
# {'coord': {'lon': -79.8667, 'lat': 8.55}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 83.14, 'feels_like': 87.1, 'temp_min': 82.51, 'temp_max': 86.29, 'pressure': 1011, 'humidity': 64, 'sea_level': 1011, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 4.79, 'deg': 339, 'gust': 6.26}, 'clouds': {'all': 96}, 'dt': 1627569035, 'sys': {'type': 2, 'id': 2011234, 'country': 'PA', 'sunrise': 1627557038, 'sunset': 1627602060}, 'timezone': -18000, 'id': 3703839, 'name': 'Nueva Gorgona', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=totness
# processing Record 40 of set 15 | totness
# {'coord': {'lon': -56.3167, 'lat': 5.8833}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 83.43, 'feels_like': 88.68, 'temp_min': 83.43, 'temp_max': 83.43, 'pressure': 1015, 'humidity': 68, 'sea_level': 1015, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 5.99, 'deg': 105, 'gust': 7.87}, 'clouds': {'all': 2}, 'dt': 1627569036, 'sys': {'country': 'SR', 'sunrise': 1627551607, 'sunset': 1627596188}, 'timezone': -10800, 'id': 3382867, 'name': 'Totness', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=bonthe
# processing Record 41 of set 15 | bonthe
# {'coord': {'lon': -12.505, 'lat': 7.5264}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 81.88, 'feels_like': 84.81, 'temp_min': 81.88, 'temp_max': 81.88, 'pressure': 1014, 'humidity': 63, 'sea_level': 1014, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 9.53, 'deg': 203, 'gust': 9.28}, 'clouds': {'all': 96}, 'dt': 1627569036, 'sys': {'country': 'SL', 'sunrise': 1627540955, 'sunset': 1627585810}, 'timezone': 0, 'id': 2409914, 'name': 'Bonthe', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=tocopilla
# processing Record 42 of set 15 | tocopilla
# {'coord': {'lon': -70.1979, 'lat': -22.092}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 68.27, 'feels_like': 67.53, 'temp_min': 68.27, 'temp_max': 68.27, 'pressure': 1016, 'humidity': 58, 'sea_level': 1016, 'grnd_level': 1006}, 'visibility': 5408, 'wind': {'speed': 7.36, 'deg': 212, 'gust': 10.6}, 'clouds': {'all': 15}, 'dt': 1627569037, 'sys': {'country': 'CL', 'sunrise': 1627557290, 'sunset': 1627597168}, 'timezone': -14400, 'id': 3869716, 'name': 'Tocopilla', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=duki
# processing Record 43 of set 15 | duki
# {'coord': {'lon': 68.5728, 'lat': 30.1541}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 93.87, 'feels_like': 94.28, 'temp_min': 93.87, 'temp_max': 93.87, 'pressure': 995, 'humidity': 34, 'sea_level': 995, 'grnd_level': 883}, 'visibility': 10000, 'wind': {'speed': 9.62, 'deg': 215, 'gust': 12.35}, 'clouds': {'all': 71}, 'dt': 1627569037, 'sys': {'country': 'PK', 'sunrise': 1627519347, 'sunset': 1627568502}, 'timezone': 18000, 'id': 1179515, 'name': 'Duki', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=borsodnadasd
# processing Record 44 of set 15 | borsodnadasd
# {'coord': {'lon': 20.25, 'lat': 48.1167}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 85.57, 'feels_like': 83.25, 'temp_min': 85.57, 'temp_max': 85.57, 'pressure': 1012, 'humidity': 29, 'sea_level': 1012, 'grnd_level': 985}, 'visibility': 10000, 'wind': {'speed': 9.84, 'deg': 289, 'gust': 13.49}, 'clouds': {'all': 0}, 'dt': 1627569038, 'sys': {'country': 'HU', 'sunrise': 1627528253, 'sunset': 1627582791}, 'timezone': 7200, 'id': 722057, 'name': 'Borsodnádasd', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=vryburg
# processing Record 45 of set 15 | vryburg
# {'coord': {'lon': 24.7284, 'lat': -26.9566}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 69.78, 'feels_like': 67.17, 'temp_min': 69.78, 'temp_max': 69.78, 'pressure': 1022, 'humidity': 15, 'sea_level': 1022, 'grnd_level': 891}, 'visibility': 10000, 'wind': {'speed': 6.93, 'deg': 228, 'gust': 8.77}, 'clouds': {'all': 0}, 'dt': 1627569038, 'sys': {'country': 'ZA', 'sunrise': 1627534989, 'sunset': 1627573905}, 'timezone': 7200, 'id': 942511, 'name': 'Vryburg', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=nakasongola
# processing Record 46 of set 15 | nakasongola
# {'coord': {'lon': 32.4564, 'lat': 1.3089}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 75.52, 'feels_like': 75.45, 'temp_min': 75.52, 'temp_max': 75.52, 'pressure': 1011, 'humidity': 57, 'sea_level': 1011, 'grnd_level': 893}, 'visibility': 10000, 'wind': {'speed': 1.77, 'deg': 38, 'gust': 3.6}, 'clouds': {'all': 96}, 'dt': 1627569038, 'sys': {'country': 'UG', 'sunrise': 1627530675, 'sunset': 1627574509}, 'timezone': 10800, 'id': 228418, 'name': 'Nakasongola', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=matoury
# processing Record 47 of set 15 | matoury
# {'coord': {'lon': -52.3317, 'lat': 4.8483}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 87.76, 'feels_like': 97.5, 'temp_min': 85.01, 'temp_max': 87.76, 'pressure': 1015, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 60}, 'rain': {'1h': 0.28}, 'clouds': {'all': 20}, 'dt': 1627569012, 'sys': {'type': 1, 'id': 8669, 'country': 'GF', 'sunrise': 1627550736, 'sunset': 1627595146}, 'timezone': -10800, 'id': 3380965, 'name': 'Matoury', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=winsum
# processing Record 48 of set 15 | winsum
# {'coord': {'lon': 6.5208, 'lat': 53.33}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 68.11, 'feels_like': 67.24, 'temp_min': 65.98, 'temp_max': 70.21, 'pressure': 1008, 'humidity': 56, 'sea_level': 1008, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 22.91, 'deg': 252, 'gust': 30.62}, 'clouds': {'all': 32}, 'dt': 1627569039, 'sys': {'type': 2, 'id': 2009499, 'country': 'NL', 'sunrise': 1627530327, 'sunset': 1627587307}, 'timezone': 7200, 'id': 2744337, 'name': 'Winsum', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=camacha
# processing Record 49 of set 15 | camacha
# {'coord': {'lon': -16.3333, 'lat': 33.0833}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 72.82, 'feels_like': 72.63, 'temp_min': 72.82, 'temp_max': 74.16, 'pressure': 1019, 'humidity': 60}, 'visibility': 10000, 'wind': {'speed': 14.97, 'deg': 10}, 'clouds': {'all': 40}, 'dt': 1627569040, 'sys': {'type': 1, 'id': 6902, 'country': 'PT', 'sunrise': 1627539388, 'sunset': 1627589215}, 'timezone': 3600, 'id': 2270385, 'name': 'Camacha', 'cod': 200}
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0f3451feffca5f3add2c355f6b5fbc4&q=desna
# processing Record 50 of set 15 | desna
# {'coord': {'lon': 30.7605, 'lat': 50.9273}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 89.02, 'feels_like': 92.41, 'temp_min': 87.51, 'temp_max': 90.81, 'pressure': 1006, 'humidity': 49, 'sea_level': 1006, 'grnd_level': 993}, 'visibility': 10000, 'wind': {'speed': 7.96, 'deg': 221, 'gust': 12.71}, 'clouds': {'all': 23}, 'dt': 1627569040, 'sys': {'type': 2, 'id': 2036058, 'country': 'UA', 'sunrise': 1627525109, 'sunset': 1627580890}, 'timezone': 10800, 'id': 710071, 'name': 'Desna', 'cod': 200}
# ---------------------------------
# Data Retrieval Complete
# ----------------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Turbat  26.0023  63.0440     93.33        53         100       14.12
# 1  Tazovskiy  67.4667  78.7000     59.22        81          43       15.48
# 2    Snizhne  48.0261  38.7723     86.20        37          12       11.18
# 3   Tasiilaq  65.6145 -37.6368     57.36        65          60        2.39
# 4  Oriximina  -1.7656 -55.8661     87.31        48          91        2.66
# 5     Lethem   3.3803 -59.7968     78.84        78          96        4.59
# 6     Vilcun -38.6500 -72.2333     38.14        69           0        0.96
# 7    Ushuaia -54.8000 -68.3000     47.82        42          40       20.71
# 8  Maniitsoq  65.4167 -52.9000     45.91        78          99        1.61
# 9       Chuy -33.6971 -53.4616     46.65        66          14       12.57
#
#   Country                 Date Current Description
# 0      PK  2021-07-29 14:25:56     overcast clouds
# 1      RU  2021-07-29 14:25:56          light rain
# 2      UA  2021-07-29 14:25:56          few clouds
# 3      GL  2021-07-29 14:25:57       broken clouds
# 4      BR  2021-07-29 14:25:57     overcast clouds
# 5      GY  2021-07-29 14:25:58     overcast clouds
# 6      CL  2021-07-29 14:25:58           clear sky
# 7      AR  2021-07-29 14:25:01    scattered clouds
# 8      GL  2021-07-29 14:25:59     overcast clouds
# 9      UY  2021-07-29 14:25:59          few clouds

# %%
new_columns = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_columns]

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file,index_label="City_ID")
